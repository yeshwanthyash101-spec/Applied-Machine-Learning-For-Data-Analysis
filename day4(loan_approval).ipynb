# %%
import pandas as pd

# %%
df=pd.read_csv("/content/loan_approval_dataset.csv")

# %%
df.head()
# Out:
#    Income  CreditScore  LoanApproved
# 0   40795          641             0
# 1   25860          698             0
# 2   63158          606             0
# 3   79343          743             1
# 4   69732          689             0

# %%
x = df[['Income','CreditScore']]
y = df['LoanApproved']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test, = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
# Import ML model
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression()
model_fit = model.fit(x_train, y_train)

# %%
model = LogisticRegression()
model.fit(x,y)
# Out:
# LogisticRegression()

# %%
yesh=model.predict(x_test)

# %%
model.predict([[40000,900]])
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([1])

# %%
predictions = model.predict(x_test)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix
accuracy = accuracy_score(y_test, yesh)
accuracy
# Out:
# 0.8833333333333333

# %%
confusion_matrix(y_test, yesh)
# Out:
# array([[35,  3],
#        [ 4, 18]])

# %%
model.predict_proba([[40000,900]])
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([[2.66091722e-04, 9.99733908e-01]])
