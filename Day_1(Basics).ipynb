# %%
print ( "Hello" )
# Out:
# Hello

# %%
#variables
a=10
b=25
print(a)
print(b)
# Out:
# 10
# 25

# %%
id(a)
# Out:
# 11654664

# %%
yeshwanth=60
print(yeshwanth)
# Out:
# 60

# %%
fr=20
print(fr)
# Out:
# 20

# %%
import keyword
keyword.iskeyword("True")
# Out:
# True

# %%
a=keyword.kwlist
len(a)
# Out:
# 35

# %%
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
"A"=="A"
# Out:
# True

# %%
#No special character should be entered while starting a cammand
_a=10
_a
# Out:
# 10

# %%
a1b=10
a1b
# Out:
# 10

# %%
a=10
b=20
print("Addition" ,a+b)
print(a-b)
print(a*b)
print(a/b)
# Out:
# Addition 30
# -10
# 200
# 0.5

# %%
a=input(6)
b=input(9)
c=input(12)
print(a,b,c)
# Out:
# 65
# 9
# 125
# 5  5

# %%
a=input("value of a")
b=input("Enter the value of b")
c=input("Enter the c value")
print(a,b,c)
# Out:
# value of a2
# Enter the value of b4
# Enter the c value6
# 2 4 6

# %%
a=input("value of a")
b=input("Enter the value of b")
c=input("Enter the c value")
#print(a,b,c)
# Out:
# value of a2
# Enter the value of b4
# Enter the c value6

# %%
a=input("value of a")
b=input("Enter the value of b")
c=input("Enter the c value")
#print(a,b,c)
print("ADD\t",a+b)
# Out:
# value of a20
# Enter the value of b30
# Enter the c value40
# ADD	 2030

# %%
a=input("value of a")
b=input("Enter the value of b")
#c=input("Enter the c value")
#print(a,b,c)
print("SUB\t",a-b)
# Out:
# value of a20
# Enter the value of b10
# Enter the c value30
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_360/1883115491.py in <cell line: 0>()
#       3 c=input("Enter the c value")
#       4 #print(a,b,c)
# ----> 5 print("SUB\t",a-b)
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'

# %%
#data type
a=10
b=10.0
c=True
d="Ram"
print(type(a))
print(type(b))
print(type(c))
print(type(d))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'bool'>
# <class 'str'>

# %%
a=input("value of a")
b=input("Enter the value of b")
#c=input("Enter the c value")
#print(a,b,c)
print("ADD\t",a-b)
print("SUB",a-b)
# Out:
# value of a9
# Enter the value of b9
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_360/741514229.py in <cell line: 0>()
#       3 #c=input("Enter the c value")
#       4 #print(a,b,c)
# ----> 5 print("ADD\t",a-b)
#       6 print("SUB",a-b)
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'

# %%
a=int(input("value of a"))
b=int(input("Enter the value of b"))
#c=input("Enter the c value")
#print(a,b,c)
print("ADD\t",a-b)
print("SUB",a-b)
# Out:
# value of a20
# Enter the value of b10
# ADD	 10
# SUB 10

# %%
sales=50000
cost=20000
profit = sales - cost

print(profit)
# Out:
# 30000

# %%
sales=int(input("value of sales"))
cost=int(input("value of cost"))
profit = sales - cost

print(profit)
# Out:
# value of sales10000
# value of cost20000
# -10000

# %%
sales=int(input("value of sales"))
cost=int(input("value of cost"))
profit = sales - cost

print(profit)
if profit>0:
  print("profit")
else:
  print("loss")
# Out:
# value of sales100000
# value of cost60000
# 40000
# profit

# %%
marks=int(input("Enter marks"))
marks=int(input("Enter marks"))
if marks>=36:
  print("PASS")
else:
  print("FAIL")
# Out:
# Enter marks13
# Enter marks40
# PASS

# %%
marks=int(input("Enter marks"))

if marks>=90 and marks<=100:
  print("A grade")
elif marks>=70 and marks<=89:
  print("B grade")
elif marks>=50 and marks<=69:
  print("C grade")
elif marks>=35 and 49:
  print("D grade")
else:
  print("FAIL")
# Out:
# Enter marks78
# B grade

# %%
#logical operater - and, or, not

# %%
list(range(5))
# Out:
# [0, 1, 2, 3, 4]

# %%
#range(START,STOP,(excluded), STEP)

# %%
list(range(1,5))
# Out:
# [1, 2, 3, 4]

# %%
salary = int(input("Enter your salary: "))
score = int(input("Enter your score: "))

if salary > 30000 and score > 700:
  print("Loan Approved!")
else:
  print("Loan Denied. Salary must be above 30,000 and score above 700.")
# Out:
# Enter your salary: 50000
# Enter your score: 600
# Loan Denied.

# %%
original_price = int(input("Enter the original price of the product: "))
discount_percentage = int(input("Enter the discount percentage (e.g., 10 for 10%): "))

discount_amount = original_price * (discount_percentage / 100)
final_price = original_price - discount_amount

print(f"Original Price: ${original_price}")
print(f"Discount ({discount_percentage}%): ${discount_amount}")
print(f"Final Price after discount: ${final_price}")

# %%
a=[1,2,3,4,5]
a
# Out:
# [1, 2, 3, 4, 5]

# %%
a[2]
# Out:
# 3

# %%
a[2]
# Out:
# 3

# %%
a[2:4]
# Out:
# [3, 4]

# %%
c=set(a)
c
# Out:
# {1, 2, 3, 4, 5}

# %%
import pandas as pd

# %%
a=[1,2,3,4,5]

# %%
type(a)
# Out:
# list

# %%
pd.DataFrame(a,index=["a","b","c","d","e"])
# Out:
#    0
# a  1
# b  2
# c  3
# d  4
# e  5

# %%
pd.DataFrame(a,index=["a","b","c","d","e"],columns=["Roll_Number"])
# Out:
#    Roll_Number
# a            1
# b            2
# c            3
# d            4
# e            5

# %%
pd.Series(a,index=['a','b','c','d','e'])
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
pd.DataFrame(d,index=['a','b','c','d'],columns=["Roll_Number"])
# Out:
#   Roll_Number
# a         NaN
# b         NaN
# c         NaN
# d         NaN

# %%
d={"sl_no":[1,2,3,4,],
   "Name":["Abhi", "Swaranraj", "Vikas", "Yogesh"]}
d
# Out:
# {'sl_no': [1, 2, 3, 4], 'Name': ['Abhi', 'Swaranraj', 'Vikas', 'Yogesh']}

# %%
d.values()
# Out:
# dict_values([[1, 2, 3, 4], ['Abhi', 'Swaranraj', 'Vikas', 'Yogesh']])

# %%
pd.DataFrame(d)
# Out:
#    sl_no       Name
# 0      1       Abhi
# 1      2  Swaranraj
# 2      3      Vikas
# 3      4     Yogesh

# %%
pd.DataFrame(d,index=['a','b','c','d'])
# Out:
#    sl_no       Name
# a      1       Abhi
# b      2  Swaranraj
# c      3      Vikas
# d      4     Yogesh

# %%
pd.DataFrame(d,index=['a','b','c','d'],columns=["Roll_Number","Student"])
# Out:
#   Roll_Number Student
# a         NaN     NaN
# b         NaN     NaN
# c         NaN     NaN
# d         NaN     NaN

# %%
df=pd.read_csv("/content/swiggy_orders_dataset.csv")

# %%
df.head()
# Out:
#    order_id       city product  price  quantity  delivery_time_min  \
# 0    100001  Davangere   Pizza    123         4                 53
# 1    100002      Hubli   Pasta    155         4                 36
# 2    100003    Belgaum  Burger    297         2                 43
# 3    100004  Davangere   Pizza    376         2                 60
# 4    100005  Mangalore   Pizza    136         2                 24
#
#   payment_method customer_type  revenue
# 0         Wallet     Returning      492
# 1            UPI           New      620
# 2            UPI           New      594
# 3            UPI     Returning      752
# 4           Card     Returning      272

# %%
df.tail()
# Out:
#       order_id       city   product  price  quantity  delivery_time_min  \
# 9995    109996  Mangalore      Dosa    227         2                 48
# 9996    109997    Belgaum     Pasta    266         2                 46
# 9997    109998     Mysore      Dosa    295         2                 23
# 9998    109999  Mangalore  Sandwich    495         5                 55
# 9999    110000     Mysore    Burger    308         5                 62
#
#      payment_method customer_type  revenue
# 9995         Wallet     Returning      454
# 9996           Card           New      532
# 9997         Wallet     Returning      590
# 9998         Wallet           New     2475
# 9999            UPI     Returning     1540

# %%
df.head(3)
# Out:
#    order_id       city product  price  quantity  delivery_time_min  \
# 0    100001  Davangere   Pizza    123         4                 53
# 1    100002      Hubli   Pasta    155         4                 36
# 2    100003    Belgaum  Burger    297         2                 43
#
#   payment_method customer_type  revenue
# 0         Wallet     Returning      492
# 1            UPI           New      620
# 2            UPI           New      594

# %%
df.tail(3)
# Out:
#       order_id       city   product  price  quantity  delivery_time_min  \
# 9997    109998     Mysore      Dosa    295         2                 23
# 9998    109999  Mangalore  Sandwich    495         5                 55
# 9999    110000     Mysore    Burger    308         5                 62
#
#      payment_method customer_type  revenue
# 9997         Wallet     Returning      590
# 9998         Wallet           New     2475
# 9999            UPI     Returning     1540

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   order_id           10000 non-null  int64
#  1   city               10000 non-null  object
#  2   product            10000 non-null  object
#  3   price              10000 non-null  int64
#  4   quantity           10000 non-null  int64
#  5   delivery_time_min  10000 non-null  int64
#  6   payment_method     10000 non-null  object
#  7   customer_type      10000 non-null  object
#  8   revenue            10000 non-null  int64
# dtypes: int64(5), object(4)
# memory usage: 703.3+ KB

# %%
df.describe()
# Out:
#            order_id         price      quantity  delivery_time_min  \
# count   10000.00000  10000.000000  10000.000000       10000.000000
# mean   105000.50000    308.503000      3.052400          39.420700
# std      2886.89568    109.617244      1.424309          14.382733
# min    100001.00000    120.000000      1.000000          15.000000
# 25%    102500.75000    213.000000      2.000000          27.000000
# 50%    105000.50000    308.000000      3.000000          40.000000
# 75%    107500.25000    404.000000      4.000000          52.000000
# max    110000.00000    499.000000      5.000000          64.000000
#
#             revenue
# count  10000.000000
# mean     939.880300
# std      571.020438
# min      120.000000
# 25%      462.000000
# 50%      830.000000
# 75%     1315.000000
# max     2495.000000

# %%
#which are the cities customers order from?
df["city"]
# Out:
# 0       Davangere
# 1           Hubli
# 2         Belgaum
# 3       Davangere
# 4       Mangalore
#           ...
# 9995    Mangalore
# 9996      Belgaum
# 9997       Mysore
# 9998    Mangalore
# 9999       Mysore
# Name: city, Length: 10000, dtype: object

# %%
df["city"].unique()
# Out:
# array(['Davangere', 'Hubli', 'Belgaum', 'Mangalore', 'Mysore', 'Tumkur',
#        'Bangalore'], dtype=object)

# %%
df["city"].value_counts()
# Out:
# city
# Belgaum      1464
# Hubli        1439
# Davangere    1429
# Mysore       1428
# Tumkur       1426
# Bangalore    1423
# Mangalore    1391
# Name: count, dtype: int64

# %%
df["city"].value_counts().idxmax()
# Out:
# 'Belgaum'

# %%
df["city"].value_counts().idxmin()
# Out:
# 'Mangalore'

# %%
df["city"].value_counts(normalize=True)
# Out:
# city
# Belgaum      0.1464
# Hubli        0.1439
# Davangere    0.1429
# Mysore       0.1428
# Tumkur       0.1426
# Bangalore    0.1423
# Mangalore    0.1391
# Name: proportion, dtype: float64

# %%
#What are the products ordered by customers?
df["product"]
# Out:
# 0          Pizza
# 1          Pasta
# 2         Burger
# 3          Pizza
# 4          Pizza
#           ...
# 9995        Dosa
# 9996       Pasta
# 9997        Dosa
# 9998    Sandwich
# 9999      Burger
# Name: product, Length: 10000, dtype: object

# %%
df["product"].value_counts()
# Out:
# product
# Burger        1275
# Noodles       1274
# Pizza         1265
# Fried Rice    1264
# Pasta         1253
# Dosa          1251
# Sandwich      1221
# Biryani       1197
# Name: count, dtype: int64

# %%
df["product"].value_counts().idxmax()
# Out:
# 'Burger'

# %%
df["product"].value_counts().idxmin()
# Out:
# 'Biryani'

# %%
df["product"].value_counts(normalize=True)
# Out:
# product
# Burger        0.1275
# Noodles       0.1274
# Pizza         0.1265
# Fried Rice    0.1264
# Pasta         0.1253
# Dosa          0.1251
# Sandwich      0.1221
# Biryani       0.1197
# Name: proportion, dtype: float64

# %%
df["price"]
# Out:
# 0       123
# 1       155
# 2       297
# 3       376
# 4       136
#        ...
# 9995    227
# 9996    266
# 9997    295
# 9998    495
# 9999    308
# Name: price, Length: 10000, dtype: int64

# %%
#what is the average price for a product ordered?
df["price"].mean()
# Out:
# np.float64(308.503)

# %%
df["price"].value_counts().idxmax()
# Out:
# np.int64(231)

# %%
df["price"].value_counts().idxmin()
# Out:
# np.int64(327)

# %%
#which are the products that create high revenue?
df.groupby("product")["revenue"].sum()
# Out:
# product
# Biryani       1145968
# Burger        1181994
# Dosa          1159543
# Fried Rice    1198050
# Noodles       1147403
# Pasta         1206162
# Pizza         1179411
# Sandwich      1180272
# Name: revenue, dtype: int64

# %%
df.groupby("city")["revenue"].sum()
# Out:
# 'Belgaum'

# %%
df.groupby("city")["revenue"].sum().idxmax()
# Out:
# 'Belgaum'

# %%
df["delivery_time_min"]
# Out:
# 0       53
# 1       36
# 2       43
# 3       60
# 4       24
#         ..
# 9995    48
# 9996    46
# 9997    23
# 9998    55
# 9999    62
# Name: delivery_time_min, Length: 10000, dtype: int64

# %%
df["delivery_time_min"].mean()
# Out:
# np.float64(39.4207)

# %%
#which are the payment method used by customers to make payment?
df["payment_method"]
# Out:
# 0       Wallet
# 1          UPI
# 2          UPI
# 3          UPI
# 4         Card
#          ...
# 9995    Wallet
# 9996      Card
# 9997    Wallet
# 9998    Wallet
# 9999       UPI
# Name: payment_method, Length: 10000, dtype: object

# %%
df["payment_method"].value_counts()
# Out:
# payment_method
# Card      2559
# Wallet    2535
# Cash      2493
# UPI       2413
# Name: count, dtype: int64

# %%
df["payment_method"].value_counts().idxmax()
# Out:
# 'Card'

# %%
df["payment_method"].value_counts().idxmin()
# Out:
# 'UPI'

# %%
df.groupby("customer_type")["revenue"].value_counts()
# Out:
# customer_type  revenue
# New            980        15
#                1140       15
#                480        14
#                832        14
#                960        14
#                           ..
# Returning      2380        1
#                2425        1
#                2455        1
#                2465        1
#                2490        1
# Name: count, Length: 2535, dtype: int64

# %%
df.drop("revenue",axis=1)
# Out:
#       order_id       city   product  price  quantity  delivery_time_min  \
# 0       100001  Davangere     Pizza    123         4                 53
# 1       100002      Hubli     Pasta    155         4                 36
# 2       100003    Belgaum    Burger    297         2                 43
# 3       100004  Davangere     Pizza    376         2                 60
# 4       100005  Mangalore     Pizza    136         2                 24
# ...        ...        ...       ...    ...       ...                ...
# 9995    109996  Mangalore      Dosa    227         2                 48
# 9996    109997    Belgaum     Pasta    266         2                 46
# 9997    109998     Mysore      Dosa    295         2                 23
# 9998    109999  Mangalore  Sandwich    495         5                 55
# 9999    110000     Mysore    Burger    308         5                 62
#
#      payment_method customer_type
# 0            Wallet     Returning
# ...

# %%
df.drop("customer_type",axis=1)
# Out:
#       order_id       city   product  price  quantity  delivery_time_min  \
# 0       100001  Davangere     Pizza    123         4                 53
# 1       100002      Hubli     Pasta    155         4                 36
# 2       100003    Belgaum    Burger    297         2                 43
# 3       100004  Davangere     Pizza    376         2                 60
# 4       100005  Mangalore     Pizza    136         2                 24
# ...        ...        ...       ...    ...       ...                ...
# 9995    109996  Mangalore      Dosa    227         2                 48
# 9996    109997    Belgaum     Pasta    266         2                 46
# 9997    109998     Mysore      Dosa    295         2                 23
# 9998    109999  Mangalore  Sandwich    495         5                 55
# 9999    110000     Mysore    Burger    308         5                 62
#
#      payment_method  revenue
# 0            Wallet      492
# 1               UPI      620
# ...

# %%
df.drop("revenue",axis=1,inplace=True)

# %%
df.head()
# Out:
#    order_id       city product  price  quantity  delivery_time_min  \
# 0    100001  Davangere   Pizza    123         4                 53
# 1    100002      Hubli   Pasta    155         4                 36
# 2    100003    Belgaum  Burger    297         2                 43
# 3    100004  Davangere   Pizza    376         2                 60
# 4    100005  Mangalore   Pizza    136         2                 24
#
#   payment_method customer_type
# 0         Wallet     Returning
# 1            UPI           New
# 2            UPI           New
# 3            UPI     Returning
# 4           Card     Returning

# %%
df["revenue"]=df["price"]*df["quantity"]

# %%
df.head()
# Out:
#    order_id       city product  price  quantity  delivery_time_min  \
# 0    100001  Davangere   Pizza    123         4                 53
# 1    100002      Hubli   Pasta    155         4                 36
# 2    100003    Belgaum  Burger    297         2                 43
# 3    100004  Davangere   Pizza    376         2                 60
# 4    100005  Mangalore   Pizza    136         2                 24
#
#   payment_method customer_type  revenue
# 0         Wallet     Returning      492
# 1            UPI           New      620
# 2            UPI           New      594
# 3            UPI     Returning      752
# 4           Card     Returning      272

# %%
import matplotlib.pyplot as plt
import seaborn as sns


plt.hist(x=df["city"],bins=20)
# Out:
# (array([1429.,    0.,    0., 1439.,    0.,    0., 1464.,    0.,    0.,
#            0., 1391.,    0.,    0., 1428.,    0.,    0., 1426.,    0.,
#            0., 1423.]),
#  array([0. , 0.3, 0.6, 0.9, 1.2, 1.5, 1.8, 2.1, 2.4, 2.7, 3. , 3.3, 3.6,
#         3.9, 4.2, 4.5, 4.8, 5.1, 5.4, 5.7, 6. ]),
#  <BarContainer object of 20 artists>)
